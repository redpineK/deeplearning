# %% [markdown]
# <a href="https://colab.research.google.com/github/redpineK/deeplearning/blob/master/001_mnist_cnn3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 출처 - https://pinkwink.kr/1121

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import sys
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
import numpy as np
np.random.seed(7)
import matplotlib.pyplot as plt

print('Python version : ', sys.version)
print('TensorFlow version : ', tf.__version__)
print('Keras version : ', keras.__version__)
# Out:
# Python version :  3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# TensorFlow version :  2.12.0
# Keras version :  2.12.0

# %%
img_rows = 28
img_cols = 28

(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

input_shape = (img_rows, img_cols, 1)
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 12

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), padding='same',
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1000, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        8256
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 1000)              3137000
#
#  dropout_1 (Dropout)         (None, 1000)              0
#
#  dense_1 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 3,156,098
# Trainable params: 3,156,098
# Non-trainable params: 0
# _________________________________________________________________

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
# %matplotlib inline

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
hist = model.fit(x_train, y_train,
                 batch_size=batch_size,
                 epochs=epochs,
                 verbose=1,
                 validation_data=(x_test, y_test))
# Out:
# Epoch 1/12
# 469/469 [==============================] - 16s 8ms/step - loss: 0.1889 - accuracy: 0.9435 - val_loss: 0.0495 - val_accuracy: 0.9840
# Epoch 2/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0600 - accuracy: 0.9809 - val_loss: 0.0373 - val_accuracy: 0.9883
# Epoch 3/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0441 - accuracy: 0.9865 - val_loss: 0.0272 - val_accuracy: 0.9901
# Epoch 4/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0358 - accuracy: 0.9888 - val_loss: 0.0274 - val_accuracy: 0.9908
# Epoch 5/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0288 - accuracy: 0.9909 - val_loss: 0.0241 - val_accuracy: 0.9917
# Epoch 6/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.0206 - val_accuracy: 0.9936
# Epoch 7/12
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.0215 - val_accuracy: 0.9934
# Epoch 8/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0239 - val_accuracy: 0.9925
# Epoch 9/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0243 - val_accuracy: 0.9914
# Epoch 10/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.0198 - val_accuracy: 0.9940
# Epoch 11/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0152 - accuracy: 0.9949 - val_loss: 0.0222 - val_accuracy: 0.9930
# Epoch 12/12
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0241 - val_accuracy: 0.9936

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.024090144783258438
# Test accuracy: 0.9936000108718872

# %%
n = 0
plt.imshow(x_test[n].reshape(28, 28), cmap='Greys', interpolation='nearest')
plt.show()

print('The Answer is ', model.predict(x_test[n].reshape((1, 28, 28, 1))))
print('The Answer is ', np.argmax(model.predict(x_test[n].reshape((1, 28, 28, 1)))))
# predictions = model.predict_classes(x_test[n])
# y_predict = np.argmax(model.predict(x_test[n]), axis=-1)print('The Answer is ', model.predict(x_test[n].reshape((1, 28, 28, 1))))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# The Answer is  [[7.7876290e-14 1.8557506e-09 1.2080187e-12 1.3429276e-10 4.6382785e-12
#   1.5519272e-14 9.6607561e-19 1.0000000e+00 8.3280191e-14 5.8138833e-10]]
# 1/1 [==============================] - 0s 17ms/step
# The Answer is  7

# %%
import random

predicted_result = model.predict(x_test)
predicted_labels = np.argmax(predicted_result, axis=1)

test_labels = np.argmax(y_test, axis=1)

wrong_result = []

for n in range(0, len(test_labels)):
    if predicted_labels[n] != test_labels[n]:
        wrong_result.append(n)

samples = random.choices(population=wrong_result, k=16)

count = 0
nrows = ncols = 4

plt.figure(figsize=(12,8))

for n in samples:
    count += 1
    plt.subplot(nrows, ncols, count)
    plt.imshow(x_test[n].reshape(28, 28), cmap='Greys', interpolation='nearest')
    tmp = "Label:" + str(test_labels[n]) + ", Prediction:" + str(predicted_labels[n])
    plt.title(tmp)

plt.tight_layout()
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
