# %% [markdown]
# <a href="https://colab.research.google.com/github/redpineK/deeplearning/blob/master/object_tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 출처 - https://github.com/RizwanMunawar/yolov8-object-tracking

# %%
# !git clone https://github.com/RizwanMunawar/yolov8-object-tracking.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 10596, done.
# remote: Counting objects: 100% (1441/1441), done.
# remote: Compressing objects: 100% (620/620), done.
# remote: Total 10596 (delta 893), reused 1238 (delta 805), pack-reused 9155
# Receiving objects: 100% (10596/10596), 6.88 MiB | 20.72 MiB/s, done.
# Resolving deltas: 100% (7087/7087), done.

# %%
# !pip install -r ultralytics/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.7/611.7 kB 16.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load a pretrained YOLOv8n model

model.train(data="coco128.yaml")  # train the model
model.val()  # evaluate model performance on the validation set
model.predict(source="https://ultralytics.com/images/bus.jpg",save=True)  # predict on an image
model.export(format="onnx")  # export the model to ONNX format

# %%
model.predict(source="https://ultralytics.com/images/bus.jpg",save=True)
model.export(format="onnx")  # export the model to ONNX format
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# Ultralytics YOLOv8.0.120 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# PyTorch: starting from runs/detect/train/weights/best.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 0.9s, saved as runs/detect/train/weights/best.onnx (12.2 MB)
#
# Export complete (1.3s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train/weights/best.onnx imgsz=640 data=/usr/local/lib/python3.10/dist-packages/ultralytics/datasets/coco128.yaml
# ...

# %%
model.names

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2 as cv
from google.colab.patches import cv2_imshow
img = cv.imread('/content/runs/detect/predict/bus.jpg',cv.IMREAD_ANYCOLOR)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080 at 0x7F22701DCE20>
